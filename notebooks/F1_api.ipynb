# %%
import requests
import pandas as pd

# %% [markdown]
# APIs:
# http://ergast.com/mrd/
# https://api.openf1.org/

# %% [markdown]
# Main routes:
# 1. Driver's (and/or team's) performance in last x races determine performance in this/next race
# 2. Same as above but with performance in pre-race sessions as determinant
# Note: Major reg changes in 2022, and new in 2026
# Other ideas:
# 1. Car data: DRS Utilization: Analyze the effectiveness of DRS zones by correlating DRS activation with speed increments.
# 2. Driver Performance Metrics: Compare performance statistics across different drivers / Team Dynamics: Analyze how driver pairings within teams influence overall team performance.
# 3. Pace Assessment: Determine the consistency of a driver's lap times relative to others.
# 6. Historical Comparisons: Compare data across different meetings to identify performance trends.
# 7. Pit Strategy Evaluation: Assess the effectiveness of pit stop strategies and their impact on race outcomes.
# 9. (maybe?) Safety Assessments: Analyze the frequency and causes of race incidents
# 10. Preparation Analysis: Evaluate how practice session performances translate to race results.
# 11. Tire Management: Assess tire performance and degradation over stints. / Fuel Strategy: Analyze fuel load management and its effect on lap times.
# 12. Driver Feedback: Understand driver concerns and feedback during the race. <- wordcloud could be funny except it's mp3s not transcripts...
# 13. Performance Correlation: Analyze how weather conditions affect car and driver performance. / Strategic Planning: Assess how teams adapt strategies based on weather forecasts.

# %% [markdown]
# List of races for 2023 and 2024:

# %%
URL = 'https://api.openf1.org/v1/meetings?year=2024&csv=true'
races_2024 = pd.read_csv(URL)

# %%
races_2024.to_csv('../data/races_2024.csv')

# %%
URL = 'https://api.openf1.org/v1/meetings?year=2023&csv=true'
races_2023 = pd.read_csv(URL)

# %%
races = [races_2023, races_2024]
races_df = pd.concat(races).reset_index(drop=True)

# %%
races_2023.to_csv('../data/races_2023.csv')

# %%
races_df
# Out:
#     circuit_key  circuit_short_name country_code  country_key  \
# 0            63              Sakhir          BRN           36
# 1            63              Sakhir          BRN           36
# 2           149              Jeddah          KSA          153
# 3            10           Melbourne          AUS            5
# 4           144                Baku          AZE           30
# 5           151               Miami          USA           19
# 6            22         Monte Carlo          MON          114
# 7            15           Catalunya          ESP            1
# 8            23            Montreal          CAN           46
# 9            19           Spielberg          AUT           17
# 10            2         Silverstone          GBR            2
# 11            4         Hungaroring          HUN           14
# 12            7   Spa-Francorchamps          BEL           16
# 13           55           Zandvoort          NED          133
# 14           39               Monza          ITA           13
# 15           61           Singapore          SGP          157
# 16           46              Suzuka          JPN            4
# 17          150              Lusail          QAT          149
# 18            9              Austin          USA           19
# 19           65         Mexico City          MEX            8
# 20           14          Interlagos          BRA           10
# 21          152           Las Vegas          USA           19
# 22           70  Yas Marina Circuit          UAE           21
# 23           63              Sakhir          BRN           36
# 24          149              Jeddah          KSA          153
# 25           10           Melbourne          AUS            5
# 26           46              Suzuka          JPN            4
# 27           49            Shanghai          CHN           53
# 28          151               Miami          USA           19
# 29            6               Imola          ITA           13
# 30           22         Monte Carlo          MON          114
# 31           23            Montreal          CAN           46
# 32           15           Catalunya          ESP            1
# 33           19           Spielberg          AUT           17
# 34            2         Silverstone          GBR            2
# 35            4         Hungaroring          HUN           14
# 36            7   Spa-Francorchamps          BEL           16
# 37           55           Zandvoort          NED          133
# 38           39               Monza          ITA           13
# 39          144                Baku          AZE           30
# 40           61           Singapore          SGP          157
# 41            9              Austin          USA           19
# 42           65         Mexico City          MEX            8
# 43           14          Interlagos          BRA           10
# 44          152           Las Vegas          USA           19
# 45          150              Lusail          QAT          149
# 46           70  Yas Marina Circuit          UAE           21
#
#             country_name                 date_start gmt_offset  \
# 0                Bahrain  2023-02-23 07:00:00+00:00   03:00:00
# 1                Bahrain  2023-03-03 11:30:00+00:00   03:00:00
# 2           Saudi Arabia  2023-03-17 13:30:00+00:00   03:00:00
# 3              Australia  2023-03-31 01:30:00+00:00   11:00:00
# 4             Azerbaijan  2023-04-28 09:30:00+00:00   04:00:00
# 5          United States  2023-05-05 18:00:00+00:00  -04:00:00
# 6                 Monaco  2023-05-26 11:30:00+00:00   02:00:00
# 7                  Spain  2023-06-02 11:30:00+00:00   02:00:00
# 8                 Canada  2023-06-16 17:30:00+00:00  -04:00:00
# 9                Austria  2023-06-30 15:00:00+00:00   02:00:00
# 10         Great Britain  2023-07-07 11:30:00+00:00   01:00:00
# 11               Hungary  2023-07-21 11:30:00+00:00   02:00:00
# 12               Belgium  2023-07-28 11:30:00+00:00   02:00:00
# 13           Netherlands  2023-08-25 10:30:00+00:00   02:00:00
# 14                 Italy  2023-09-01 11:30:00+00:00   02:00:00
# 15             Singapore  2023-09-15 09:30:00+00:00   08:00:00
# 16                 Japan  2023-09-22 02:30:00+00:00   09:00:00
# 17                 Qatar  2023-10-06 13:30:00+00:00   03:00:00
# 18         United States  2023-10-20 17:30:00+00:00  -05:00:00
# 19                Mexico  2023-10-27 18:30:00+00:00  -06:00:00
# 20                Brazil  2023-11-03 14:30:00+00:00  -03:00:00
# 21         United States  2023-11-17 04:30:00+00:00  -08:00:00
# 22  United Arab Emirates  2023-11-24 09:30:00+00:00   04:00:00
# 23               Bahrain  2024-02-29 11:30:00+00:00   03:00:00
# 24          Saudi Arabia  2024-03-07 13:30:00+00:00   03:00:00
# 25             Australia  2024-03-22 01:30:00+00:00   11:00:00
# 26                 Japan  2024-04-05 02:30:00+00:00   09:00:00
# 27                 China  2024-04-19 03:30:00+00:00   08:00:00
# 28         United States  2024-05-03 16:30:00+00:00  -04:00:00
# 29                 Italy  2024-05-17 11:30:00+00:00   02:00:00
# 30                Monaco  2024-05-24 11:30:00+00:00   02:00:00
# 31                Canada  2024-06-07 17:30:00+00:00  -04:00:00
# 32                 Spain  2024-06-21 11:30:00+00:00   02:00:00
# 33               Austria  2024-06-28 10:30:00+00:00   02:00:00
# 34         Great Britain  2024-07-05 11:30:00+00:00   01:00:00
# 35               Hungary  2024-07-19 11:30:00+00:00   02:00:00
# 36               Belgium  2024-07-26 11:30:00+00:00   02:00:00
# 37           Netherlands  2024-08-23 10:30:00+00:00   02:00:00
# 38                 Italy  2024-08-30 11:30:00+00:00   02:00:00
# 39            Azerbaijan  2024-09-13 09:30:00+00:00   04:00:00
# 40             Singapore  2024-09-20 09:30:00+00:00   08:00:00
# 41         United States  2024-10-18 17:30:00+00:00  -05:00:00
# 42                Mexico  2024-10-25 18:30:00+00:00  -06:00:00
# 43                Brazil  2024-11-01 14:30:00+00:00  -03:00:00
# 44         United States  2024-11-22 02:30:00+00:00  -08:00:00
# 45                 Qatar  2024-11-29 13:30:00+00:00   03:00:00
# 46  United Arab Emirates  2024-12-06 09:30:00+00:00   04:00:00
#
#              location meeting_code  meeting_key               meeting_name  \
# 0              Sakhir          NaN         1140         Pre-Season Testing
# 1              Sakhir          NaN         1141         Bahrain Grand Prix
# 2              Jeddah          NaN         1142   Saudi Arabian Grand Prix
# 3           Melbourne          NaN         1143      Australian Grand Prix
# 4                Baku          NaN         1207      Azerbaijan Grand Prix
# 5               Miami          NaN         1208           Miami Grand Prix
# 6              Monaco          NaN         1210          Monaco Grand Prix
# 7           Barcelona          NaN         1211         Spanish Grand Prix
# 8            Montréal          NaN         1212        Canadian Grand Prix
# 9           Spielberg          AUT         1213        Austrian Grand Prix
# 10        Silverstone          NaN         1214         British Grand Prix
# 11           Budapest          NaN         1215       Hungarian Grand Prix
# 12  Spa-Francorchamps          NaN         1216         Belgian Grand Prix
# 13          Zandvoort          NaN         1217           Dutch Grand Prix
# 14              Monza          NaN         1218         Italian Grand Prix
# 15         Marina Bay          NaN         1219       Singapore Grand Prix
# 16             Suzuka          NaN         1220        Japanese Grand Prix
# 17             Lusail          NaN         1221           Qatar Grand Prix
# 18             Austin          NaN         1222   United States Grand Prix
# 19        Mexico City          NaN         1223     Mexico City Grand Prix
# 20          São Paulo          NaN         1224       São Paulo Grand Prix
# 21          Las Vegas          NaN         1225       Las Vegas Grand Prix
# 22         Yas Island          NaN         1226       Abu Dhabi Grand Prix
# 23             Sakhir          BRN         1229         Bahrain Grand Prix
# 24             Jeddah          KSA         1230   Saudi Arabian Grand Prix
# 25          Melbourne          AUS         1231      Australian Grand Prix
# 26             Suzuka          JPN         1232        Japanese Grand Prix
# 27           Shanghai          CHN         1233         Chinese Grand Prix
# 28              Miami          USA         1234           Miami Grand Prix
# 29              Imola          ITA         1235  Emilia Romagna Grand Prix
# 30             Monaco          MON         1236          Monaco Grand Prix
# 31           Montréal          CAN         1237        Canadian Grand Prix
# 32          Barcelona          ESP         1238         Spanish Grand Prix
# 33          Spielberg          AUT         1239        Austrian Grand Prix
# 34        Silverstone          GBR         1240         British Grand Prix
# 35           Budapest          HUN         1241       Hungarian Grand Prix
# 36  Spa-Francorchamps          BEL         1242         Belgian Grand Prix
# 37          Zandvoort          NED         1243           Dutch Grand Prix
# 38              Monza          ITA         1244         Italian Grand Prix
# 39               Baku          AZE         1245      Azerbaijan Grand Prix
# 40         Marina Bay          SGP         1246       Singapore Grand Prix
# 41             Austin          USA         1247   United States Grand Prix
# 42        Mexico City          MEX         1248     Mexico City Grand Prix
# 43          São Paulo          BRA         1249       São Paulo Grand Prix
# 44          Las Vegas          USA         1250       Las Vegas Grand Prix
# 45             Lusail          QAT         1251           Qatar Grand Prix
# 46         Yas Island          UAE         1252       Abu Dhabi Grand Prix
#
#                                 meeting_official_name  year
# 0            FORMULA 1 ARAMCO PRE-SEASON TESTING 2023  2023
# 1          FORMULA 1 GULF AIR BAHRAIN GRAND PRIX 2023  2023
# 2         FORMULA 1 STC SAUDI ARABIAN GRAND PRIX 2023  2023
# 3          FORMULA 1 ROLEX AUSTRALIAN GRAND PRIX 2023  2023
# 4                FORMULA 1 AZERBAIJAN GRAND PRIX 2023  2023
# 5          FORMULA 1 CRYPTO.COM MIAMI GRAND PRIX 2023  2023
# 6                 FORMULA 1 GRAND PRIX DE MONACO 2023  2023
# 7            FORMULA 1 AWS GRAN PREMIO DE ESPAÑA 2023  2023
# 8         FORMULA 1 PIRELLI GRAND PRIX DU CANADA 2023  2023
# 9   FORMULA 1 ROLEX GROSSER PREIS VON ÖSTERREICH 2023  2023
# 10           FORMULA 1 ARAMCO BRITISH GRAND PRIX 2023  2023
# 11  FORMULA 1 QATAR AIRWAYS HUNGARIAN GRAND PRIX 2023  2023
# 12      FORMULA 1 MSC CRUISES BELGIAN GRAND PRIX 2023  2023
# 13           FORMULA 1 HEINEKEN DUTCH GRAND PRIX 2023  2023
# 14        FORMULA 1 PIRELLI GRAN PREMIO D’ITALIA 2023  2023
# 15  FORMULA 1 SINGAPORE AIRLINES SINGAPORE GRAND P...  2023
# 16          FORMULA 1 LENOVO JAPANESE GRAND PRIX 2023  2023
# 17      FORMULA 1 QATAR AIRWAYS QATAR GRAND PRIX 2023  2023
# 18     FORMULA 1 LENOVO UNITED STATES GRAND PRIX 2023  2023
# 19  FORMULA 1 GRAN PREMIO DE LA CIUDAD DE MÉXICO 2023  2023
# 20    FORMULA 1 ROLEX GRANDE PRÊMIO DE SÃO PAULO 2023  2023
# 21  FORMULA 1 HEINEKEN SILVER LAS VEGAS GRAND PRIX...  2023
# 22  FORMULA 1 ETIHAD AIRWAYS ABU DHABI GRAND PRIX ...  2023
# 23         FORMULA 1 GULF AIR BAHRAIN GRAND PRIX 2024  2024
# 24        FORMULA 1 STC SAUDI ARABIAN GRAND PRIX 2024  2024
# 25         FORMULA 1 ROLEX AUSTRALIAN GRAND PRIX 2024  2024
# 26     FORMULA 1 MSC CRUISES JAPANESE GRAND PRIX 2024  2024
# 27           FORMULA 1 LENOVO CHINESE GRAND PRIX 2024  2024
# 28         FORMULA 1 CRYPTO.COM MIAMI GRAND PRIX 2024  2024
# 29  FORMULA 1 MSC CRUISES GRAN PREMIO DEL MADE IN ...  2024
# 30                FORMULA 1 GRAND PRIX DE MONACO 2024  2024
# 31            FORMULA 1 AWS GRAND PRIX DU CANADA 2024  2024
# 32        FORMULA 1 ARAMCO GRAN PREMIO DE ESPAÑA 2024  2024
# 33   FORMULA 1 QATAR AIRWAYS AUSTRIAN GRAND PRIX 2024  2024
# 34    FORMULA 1 QATAR AIRWAYS BRITISH GRAND PRIX 2024  2024
# 35                FORMULA 1 HUNGARIAN GRAND PRIX 2024  2024
# 36            FORMULA 1 ROLEX BELGIAN GRAND PRIX 2024  2024
# 37           FORMULA 1 HEINEKEN DUTCH GRAND PRIX 2024  2024
# 38        FORMULA 1 PIRELLI GRAN PREMIO D’ITALIA 2024  2024
# 39  FORMULA 1 QATAR AIRWAYS AZERBAIJAN GRAND PRIX ...  2024
# 40  FORMULA 1 SINGAPORE AIRLINES SINGAPORE GRAND P...  2024
# 41    FORMULA 1 PIRELLI UNITED STATES GRAND PRIX 2024  2024
# 42  FORMULA 1 GRAN PREMIO DE LA CIUDAD DE MÉXICO 2024  2024
# 43   FORMULA 1 LENOVO GRANDE PRÊMIO DE SÃO PAULO 2024  2024
# 44  FORMULA 1 HEINEKEN SILVER LAS VEGAS GRAND PRIX...  2024
# 45      FORMULA 1 QATAR AIRWAYS QATAR GRAND PRIX 2024  2024
# 46  FORMULA 1 ETIHAD AIRWAYS ABU DHABI GRAND PRIX ...  2024

# %%
races_df.to_csv('../data/races_df.csv')

# %% [markdown]
# List of sessions for 2023 and 2024:
# (A session includes 1 or 3 non-competitive 'Free Practice' sessions, qualifying, (sprint-quali and sprint?), and race)

# %%
URL = 'https://api.openf1.org/v1/sessions?year=2024&csv=true'
sessions_2024 = pd.read_csv(URL)

# %%
sessions_2024.to_csv('../data/sessions_2024.csv')

# %%
URL = 'https://api.openf1.org/v1/sessions?year=2023&csv=true'
sessions_2023 = pd.read_csv(URL)

# %%
sessions_2023.to_csv('../data/sessions_2023.csv')

# %%
sessions = [sessions_2023, sessions_2024]
sessions_df = pd.concat(sessions).reset_index(drop=True)

# %%
sessions_df.to_csv('../data/sessions_df.csv')

# %% [markdown]
# Extracting keys for just race sessions to use in a bit:

# %%
races = sessions_df[sessions_df['session_name'] == 'Race']
race_keys = pd.array(races['session_key'])

# %%
race_keys
# Out:
# <NumpyExtensionArray>
# [7953, 7779, 7787, 9070, 9078, 9094, 9102, 9110, 9118, 9126, 9133, 9141, 9149,
#  9157, 9165, 9173, 9221, 9213, 9181, 9205, 9189, 9197, 9472, 9480, 9488, 9496,
#  9673, 9507, 9515, 9523, 9531, 9539, 9550, 9558, 9566, 9574, 9582, 9590, 9598,
#  9606, 9617, 9625, 9636, 9644, 9655, 9662]
# Length: 46, dtype: int64

# %% [markdown]
# Compiling list of drivers for 2023 and 2024 seasons:

# %%
drivers = []
for x in race_keys:
    data = pd.read_csv(f'https://api.openf1.org/v1/drivers?session_key={x}&csv=true')
    drivers.append(data)
drivers_df = pd.concat(drivers, ignore_index=True)

# %%
drivers_df.to_csv('../data/drivers_df.csv')

# %%
drivers_df#['full_name'].unique()
# Out:
#     broadcast_name country_code  driver_number first_name        full_name  \
# 0     M VERSTAPPEN          NaN              1        NaN   Max VERSTAPPEN
# 1       L SARGEANT          NaN              2        NaN   Logan SARGEANT
# 2         L NORRIS          NaN              4        NaN     Lando NORRIS
# 3          P GASLY          NaN             10        NaN     Pierre GASLY
# 4          S PEREZ          NaN             11        NaN     Sergio PEREZ
# ..             ...          ...            ...        ...              ...
# 913        C SAINZ          ESP             55     Carlos     Carlos SAINZ
# 914       J DOOHAN          NaN             61        NaN      Jack DOOHAN
# 915      G RUSSELL          GBR             63     George   George RUSSELL
# 916       V BOTTAS          FIN             77   Valtteri  Valtteri BOTTAS
# 917      O PIASTRI          AUS             81      Oscar    Oscar PIASTRI
#
#                                           headshot_url last_name  meeting_key  \
# 0                                                  NaN       NaN         1141
# 1                                                  NaN       NaN         1141
# 2                                                  NaN       NaN         1141
# 3                                                  NaN       NaN         1141
# 4                                                  NaN       NaN         1141
# ..                                                 ...       ...          ...
# 913  https://media.formula1.com/d_driver_fallback_i...     Sainz         1252
# 914                                                NaN       NaN         1252
# 915  https://media.formula1.com/d_driver_fallback_i...   Russell         1252
# 916  https://media.formula1.com/d_driver_fallback_i...    Bottas         1252
# 917  https://media.formula1.com/d_driver_fallback_i...   Piastri         1252
#
#     name_acronym  session_key team_colour    team_name
# 0            VER         7953         NaN          NaN
# 1            SAR         7953         NaN          NaN
# 2            NOR         7953         NaN          NaN
# 3            GAS         7953         NaN          NaN
# 4            PER         7953         NaN          NaN
# ..           ...          ...         ...          ...
# 913          SAI         9662      E80020      Ferrari
# 914          DOO         9662         NaN          NaN
# 915          RUS         9662      27F4D2     Mercedes
# 916          BOT         9662      52E252  Kick Sauber
# 917          PIA         9662      FF8000      McLaren
#
# [918 rows x 12 columns]

# %% [markdown]
# Credit to weiranyu (Github) for the original code to pull from ergast F1 API (modified for my needs)

# %% [markdown]
# List of drivers for 2023 and 2024 (using ergast)

# %%
year = 2024
URL = 'http://ergast.com/api/f1/{}/drivers.json?limit=1000'.format(year)
drivers_2024_json = requests.get(URL).json()
drivers_2024_er = pd.DataFrame(drivers_2024_json["MRData"]["DriverTable"]['Drivers'])

# %%
drivers_2024_er.to_csv('../data/drivers_2024_er.csv')

# %%
year = 2023
URL = 'http://ergast.com/api/f1/{}/drivers.json?limit=1000'.format(year)
drivers_2023_json = requests.get(URL).json()
drivers_2023_er = pd.DataFrame(drivers_2023_json["MRData"]["DriverTable"]['Drivers'])

# %% [markdown]
# List of constructors for 2024

# %%
year = 2024
URL = 'http://ergast.com/api/f1/{}/constructors.json?limit=1000'.format(year)
teams_2024_json = requests.get(URL).json()
teams_2024_er = pd.DataFrame(teams_2024_json["MRData"]["ConstructorTable"]['Constructors'])

# %%
teams_2024_er.to_csv('../data/teams_2024_er.csv')

# %% [markdown]
# Race results for 2024

# %%
year = 2024
for x in range(1,2):
    URL = 'http://ergast.com/api/f1/{}/{}/results.json?limit=1000'.format(year, x)
    data = requests.get(URL).json()
    results_24.append(data)
results_24
#drivers_df = pd.concat(drivers, ignore_index=True)
